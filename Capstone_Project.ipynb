# %% [markdown]
# # Final Capstone Project
# *Sébastien Lozano Forero*
#
# # Week 1
#
# In this notebook, the final project of Coursera's IBM Data Science Specialization is going to be presented.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# # Week 2

# %% [markdown]
# ## Description of the problem

# %% [markdown]
# Road safety is notheworty to be studied around the globe in the current days. Due to the economical improvemnt achiveved in many countries in the last half century, the use of vehicles has grew consistently through time. At the same time, the numbers of accidents involving  injured and killed people has also grew up rapidly. So, answering questions as **How car accidents might be avoided?** end up being stimulating problem. So, the more knowledge is possible to gather and use around the accidents, the better actions can be taken in the near future in order to improve safety in the streets and reduce lifes losses from preventable accidents. This projects aims to contribute to this goal based on the Data Science approach.

# %% [markdown]
# ## Description of the Data

# %% [markdown]
# First, let us import the dataset (if you are looking forward to run the code, gotta be patience because this is a really large cvs file and might take a few minuts) which is a 194673 rows × 38 columns dataset.

# %%
df= pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
df
# Out:
# C:\Users\Sebmatecho\anaconda4\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 0                  2 -122.323148  47.703140         1    1307       1307
# 1                  1 -122.347294  47.647172         2   52200      52200
# 2                  1 -122.334540  47.607871         3   26700      26700
# 3                  1 -122.334803  47.604803         4    1144       1144
# 4                  2 -122.306426  47.545739         5   17700      17700
# ...              ...         ...        ...       ...     ...        ...
# 194668             2 -122.290826  47.565408    219543  309534     310814
# 194669             1 -122.344526  47.690924    219544  309085     310365
# ...

# %% [markdown]
# Let us take a quick look on the names of the features

# %%
list(df.columns)
# Out:
# ['SEVERITYCODE',
#  'X',
#  'Y',
#  'OBJECTID',
#  'INCKEY',
#  'COLDETKEY',
#  'REPORTNO',
#  'STATUS',
#  'ADDRTYPE',
#  'INTKEY',
#  'LOCATION',
#  'EXCEPTRSNCODE',
#  'EXCEPTRSNDESC',
#  'SEVERITYCODE.1',
#  'SEVERITYDESC',
#  'COLLISIONTYPE',
#  'PERSONCOUNT',
#  'PEDCOUNT',
#  'PEDCYLCOUNT',
#  'VEHCOUNT',
#  'INCDATE',
#  'INCDTTM',
#  'JUNCTIONTYPE',
#  'SDOT_COLCODE',
#  'SDOT_COLDESC',
#  'INATTENTIONIND',
#  'UNDERINFL',
#  'WEATHER',
#  'ROADCOND',
#  'LIGHTCOND',
#  'PEDROWNOTGRNT',
#  'SDOTCOLNUM',
#  'SPEEDING',
#  'ST_COLCODE',
#  'ST_COLDESC',
#  'SEGLANEKEY',
#  'CROSSWALKKEY',
#  'HITPARKEDCAR']

# %%
df.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY      COLDETKEY         INTKEY  SEVERITYCODE.1  \
# count  194673.000000  194673.000000   65070.000000   194673.000000
# mean   141091.456350  141298.811381   37558.450576        1.298901
# std     86634.402737   86986.542110   51745.990273        0.457778
# min      1001.000000    1001.000000   23807.000000        1.000000
# ...

# %% [markdown]
# Possibly not of all these features will be useful to our end. Nevertheless, there is some valuable ones in which we should draw our attention. This way, our aim is trying to predict the output SEVERITYCODE (how serious a crash was) and a good starting point should be considering conditions of the road (variable ROADCOND), wheater conditions at the moment of the accident (WHEATHER), light conditions (variable LIGHTCOND), if any involved vehicle was speeding (variable SPEEDING), location of the accident (variable LOCATION), number of vehicles involved (variable VEHCOUNT), among others.
